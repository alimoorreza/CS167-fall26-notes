# %% [markdown]
# <a href="https://colab.research.google.com/github/alimoorreza/CS167-fall26-notes/blob/main/Day08_Graphplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS167: Day08
# ## Graph Plot
#
# #### CS167: Machine Learning, Fall 2026
#
#
# 📜 [Syllabus](https://analytics.drake.edu/~reza/teaching/cs167_fall26/cs167_syllabus_fall26.pdf)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

#define our data
xvals   = [1,2,3,4,5]
series1 = [0.66,0.61,0.69,0.73,0.77]
series2 = [0.8,0.83,0.77,0.81,0.79]
series3 = [0.55,0.67,0.5,0.73,0.66]

#add titles to axis and graph
plt.suptitle('my rocking plot', fontsize=16)
plt.xlabel('a very cool x axis')
plt.ylabel('awesome y axis')

#plot the data first along with pattern/display markers
#         x-axis values,  y-axis values   color/pattern/etc   name to refer to the pattern
plt.plot(xvals,           series1,        'ro--',             label='1st series')
plt.plot(xvals,           series2,        'bs-.',             label='2nd series')
plt.plot(xvals,           series3,        'g^-',              label='3rd series')

plt.legend() #plt.legend(loc='lower right', shadow=True)

# Tweak the next method so that you can display different ranges of values along the x-axis and y-axis.
plt.axis([
          0,     #lowest  value along x-axis
          6,     #highest value along x-axis
          0,     #lowest  value along y-axis
          1      #highest value along y-axis
          ])

plt.show()

# %% [markdown]
# ## Use markers to differentiate your series:

# %%
# %%html
# <iframe src="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html" width="1500" height="500"></iframe>
# Out:
# <iframe src="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html" width="1500" height="500"></iframe>

# %% [markdown]
# # A simple example:

# %%
# load in the vehicles.csv data for scikit learn
import pandas
import numpy

# load data, get the right subset
path = '/content/drive/MyDrive/cs167_fall26/datasets/vehicles.csv'
data = pandas.read_csv(path)
gas_vehicles = data[data['fuelType']=='Regular'][['year', 'cylinders', 'displ', 'comb08']]
gas_vehicles.dropna(inplace=True)
# Out:
# /tmp/ipykernel_3672/1133439839.py:7: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pandas.read_csv(path)

# %%
gas_vehicles = data[data['fuelType']=='Regular']

# a silly function that returns the average MPG for the first k cars in the df
def getAverageMPG(data, k):
    return data["comb08"].iloc[0:k].mean()

number_of_points = 500

#populate the series list
series = []
for i in range(1, number_of_points):
    val = getAverageMPG(gas_vehicles, i)
    series.append(val)

#plot it!
xvals = range(1, number_of_points)
plt.suptitle('Average MPG', fontsize=18)
plt.xlabel('cars used in average')
plt.ylabel('average MPG')
plt.plot(xvals, series, '.-r', label='MPG')
plt.legend(loc='lower right', shadow=True)
plt.axis([1, number_of_points, 10,25])
plt.show()

# %% [markdown]
# # 💬 Exercise #1:
#
# Given the code from the previous cell:
# - change the number of points to 20
# - Change the marker of the mean curve to **green dots** with a **solid line** style
# - Also, plot the median using a **red circle marker** with a **solid line** style

# %%
gas_vehicles = data[data['fuelType']=='Regular']

# a silly function that returns the average MPG for the first k cars in the df
def getAverageMPG(data, k):
    # your code
    # ...


def getMedianMPG(data, k):
    # your code
    # ...


number_of_points = 500

#populate the series list
series = []
series_median = []
for i in range(1, number_of_points):
    val = getAverageMPG(gas_vehicles, i)
    val2 = getMedianMPG(gas_vehicles, i)
    series.append(val)

#plot it!
# your code
# ...
